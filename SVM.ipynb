# %% [markdown]
# ### Logistic Regression

# %%
logreg = LogisticRegression(max_iter=500, solver='lbfgs')
logreg.fit(X_train, y_train)

plot_decision_boundary(logreg, X_test, y_test, "Logistic Regression")
print("Accuracy:", accuracy_score(y_test, logreg.predict(X_test)))
# Out:
# Accuracy: 0.8333333333333334

# %% [markdown]
# ## SVM

# %%
svm_linear = SVC(kernel='linear')
svm_linear.fit(X_train, y_train)
plot_decision_boundary(svm_linear, X_test, y_test, "SVM (Linear Kernel)")

# %% [markdown]
# ## KNN

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
plot_decision_boundary(knn, X_test, y_test, "KNN (Linear Kernel)")

# %% [markdown]
# ## Decision Tree

# %%
clf = DecisionTreeClassifier(max_depth=4)
clf.fit(X_train, y_train)
plot_decision_boundary(clf, X_test, y_test, f"Decision Tree (depth={4})")

# %% [markdown]
# ### Random Forest

# %%
for n in [1, 10, 100]:
    clf = RandomForestClassifier(n_estimators=n, max_depth=3)
    clf.fit(X_train, y_train)
    plot_decision_boundary(clf, X_test, y_test, f"Random Forest (n_estimators={n})")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2225975066> in <cell line: 0>()
#       1 for n in [1, 10, 100]:
# ----> 2     clf = RandomForestClassifier(n_estimators=n, max_depth=3)
#       3     clf.fit(X_train, y_train)
#       4     plot_decision_boundary(clf, X_test, y_test, f"Random Forest (n_estimators={n})")
#
# NameError: name 'RandomForestClassifier' is not defined

# %% [markdown]
# ### XGBoost

# %%
clf = XGBClassifier(n_estimators=10, learning_rate=0.1, max_depth=3, eval_metric='logloss')
clf.fit(X_train, y_train)
plot_decision_boundary(clf, X_test, y_test, f"XGBoost (n_estimators={10})")
