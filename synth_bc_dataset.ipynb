# %%
# Create a synthetic binary classification dataset
X, y = make_classification(n_samples=500, n_features=2, n_redundant=0,
                           n_informative=2, n_clusters_per_class=1, flip_y=0.05,
                           class_sep=1, random_state=42)

# Visualize the generated 2D feature space
plt.figure(figsize=(6, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='bwr', edgecolors='k')
plt.title("Synthetic Binary Classification Data")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3545082639> in <cell line: 0>()
#       1 # Create a synthetic binary classification dataset
# ----> 2 X, y = make_classification(n_samples=500, n_features=2, n_redundant=0,
#       3                            n_informative=2, n_clusters_per_class=1, flip_y=0.05,
#       4                            class_sep=1, random_state=42)
#       5
#
# NameError: name 'make_classification' is not defined
